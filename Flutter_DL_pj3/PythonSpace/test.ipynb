# %%
str01 = '2022-08-11 02:00'
str01.split()[0].replace('-','')
str01.split()[1].replace(':','')
# Out:
# '20220811'

# %%
import math
round(12.213)
# Out:
# 12

# %%
apikey = '3kBMQo1vri3CU+lAk+Q0d5mIuSYJGMnuXo1+Q2T3WhfM5O+bgtU5RHXNDdrLxndWkLln0vjJH9qiusisiZqonQ=='
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst'


params ={'serviceKey' : apikey, 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'JSON', 'base_date' : '20220810', 'base_time' : '0500', 'nx' : '55', 'ny' : '127' }

response = requests.get(url, params=params)
response.text
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"baseDate":"20220810","baseTime":"0500","category":"TMP","fcstDate":"20220810","fcstTime":"0600","fcstValue":"22","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"UUU","fcstDate":"20220810","fcstTime":"0600","fcstValue":"0.6","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"VVV","fcstDate":"20220810","fcstTime":"0600","fcstValue":"-1.7","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"VEC","fcstDate":"20220810","fcstTime":"0600","fcstValue":"341","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"WSD","fcstDate":"20220810","fcstTime":"0600","fcstValue":"1.8","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"SKY","fcstDate":"20220810","fcstTime":"0600","fcstValue":"4","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0500","category":"PTY","fcstDate":"20220810","
# ...

# %%
import requests
apikey = '3kBMQo1vri3CU+lAk+Q0d5mIuSYJGMnuXo1+Q2T3WhfM5O+bgtU5RHXNDdrLxndWkLln0vjJH9qiusisiZqonQ=='
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst'

url_test = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst'

params ={'serviceKey' : apikey, 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'JSON', 'base_date' : '20220810', 'base_time' : '0200', 'nx' : '55', 'ny' : '127' }

response = requests.get(url, params=params)
response.text
# tmp= response.json()['response']['body']['items']['item']
# tmp
# Out:
# '{"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"baseDate":"20220810","baseTime":"0200","category":"TMP","fcstDate":"20220810","fcstTime":"0300","fcstValue":"22","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"UUU","fcstDate":"20220810","fcstTime":"0300","fcstValue":"0","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"VVV","fcstDate":"20220810","fcstTime":"0300","fcstValue":"-2.6","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"VEC","fcstDate":"20220810","fcstTime":"0300","fcstValue":"360","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"WSD","fcstDate":"20220810","fcstTime":"0300","fcstValue":"2.6","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"SKY","fcstDate":"20220810","fcstTime":"0300","fcstValue":"4","nx":55,"ny":127},{"baseDate":"20220810","baseTime":"0200","category":"PTY","fcstDate":"20220810","fc
# ...

# %%
from datetime import datetime,timedelta
print(datetime(2020,7,1,0,00,00,0) + timedelta(hours=-2))
# Out:
# 2020-06-30 22:00:00

# %%
# Out:
#   Input In [143]
#     datetime(2020-06-30 22:00:00)
#                    ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import requests

apikey = '3kBMQo1vri3CU+lAk+Q0d5mIuSYJGMnuXo1+Q2T3WhfM5O+bgtU5RHXNDdrLxndWkLln0vjJH9qiusisiZqonQ=='
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getVilageFcst'


params ={'serviceKey' : apikey, 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'JSON', 'base_date' : '20220809', 'base_time' : '1800', 'nx' : '37.498095', 'ny' : '127.027610' }

response = requests.get(url, params=params)
print(response.json()['response']['body'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb 셀 4 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> params ={'serviceKey' : apikey, 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'JSON', 'base_date' : '20220809', 'base_time' : '1800', 'nx' : '37.498095', 'ny' : '127.027610' }
#       <a href='vscode-notebook-cell:/Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> response = requests.get(url, params=params)
# ---> <a href='vscode-notebook-cell:/Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> print(response.json()['response']['body'])
#
# KeyError: 'body'

# %%
from datetime import datetime
datetime(2022,2,2).
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb 셀 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from datetime import datetime
# ----> <a href='vscode-notebook-cell:/Users/kte/ktePy/FlutterApp/Flutter_DL_pj3/PythonSpace/test.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> datetime(20220202)
#
# TypeError: function missing required argument 'month' (pos 2)

# %%
import requests

url = 'http://apis.data.go.kr/1360000/MidFcstInfoService/getMidFcst'
params ={'serviceKey' : '3kBMQo1vri3CU+lAk+Q0d5mIuSYJGMnuXo1+Q2T3WhfM5O+bgtU5RHXNDdrLxndWkLln0vjJH9qiusisiZqonQ==', 'pageNo' : '1', 'numOfRows' : '10', 'dataType' : 'JSON', 'stnId' : '109', 'tmFc' : '202208091800' }

response = requests.get(url, params=params)
print(response.text)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"wfSv":"○ (강수) 15일(월)~16일(화)은 흐리고 비가 내리는 곳이 있겠습니다.\n○ (기온) 이번 예보기간 아침 기온은 21~27도로 오늘(9일, 아침최저기온 25~26도)보다 낮거나 비슷하겠으며, 낮 기온은 28~32도로 오늘(9일, 낮최고기온 26~29도)보다 높겠습니다. \n○ (해상) 서해중부해상의 물결은 14일(일)~15일(월)에 1.0~2.5m로 높게 일겠고, 그 밖의 날은 1.0~2.0m로 일겠습니다.\n○ (주말전망) 13일(토)과 14일(일)은 흐리겠습니다. 아침 기온은 24~26도, 낮 기온은 29~32도가 되겠습니다.\n\n* 이번 예보기간에는 북태평양고기압의 확장과 수축 정도에 따라 강수의 변동성이 크겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다."}]},"pageNo":1,"numOfRows":10,"totalCount":1}}}

# %%
response.json()
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'JSON',
#    'items': {'item': [{'wfSv': '○ (강수) 15일(월)~16일(화)은 흐리고 비가 내리는 곳이 있겠습니다.\n○ (기온) 이번 예보기간 아침 기온은 21~27도로 오늘(9일, 아침최저기온 25~26도)보다 낮거나 비슷하겠으며, 낮 기온은 28~32도로 오늘(9일, 낮최고기온 26~29도)보다 높겠습니다. \n○ (해상) 서해중부해상의 물결은 14일(일)~15일(월)에 1.0~2.5m로 높게 일겠고, 그 밖의 날은 1.0~2.0m로 일겠습니다.\n○ (주말전망) 13일(토)과 14일(일)은 흐리겠습니다. 아침 기온은 24~26도, 낮 기온은 29~32도가 되겠습니다.\n\n* 이번 예보기간에는 북태평양고기압의 확장과 수축 정도에 따라 강수의 변동성이 크겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'}]},
#    'pageNo': 1,
#    'numOfRows': 10,
#    'totalCount': 1}}}

# %%
print(len(response.json()['response']['body']['items']['item']))
# Out:
# 882

# %%
12*24
# Out:
# 288

# %%
print(response.text)
# Out:
# {"response":{"header":{"resultCode":"00","resultMsg":"NORMAL_SERVICE"},"body":{"dataType":"JSON","items":{"item":[{"baseDate":"20220809","baseTime":"2300","category":"TMP","fcstDate":"20220810","fcstTime":"0000","fcstValue":"23","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"UUU","fcstDate":"20220810","fcstTime":"0000","fcstValue":"0","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"VVV","fcstDate":"20220810","fcstTime":"0000","fcstValue":"-3","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"VEC","fcstDate":"20220810","fcstTime":"0000","fcstValue":"2","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"WSD","fcstDate":"20220810","fcstTime":"0000","fcstValue":"3","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"SKY","fcstDate":"20220810","fcstTime":"0000","fcstValue":"4","nx":55,"ny":127},{"baseDate":"20220809","baseTime":"2300","category":"PTY","fcstDate":"20220810","fcstTime"
# ...

# %%
for i in range(12):
    print(response.json()['response']['body']['items']['item'][12*i+1]['category'])
# Out:
# UUU
# UUU
# UUU
# UUU
# UUU
# UUU
# UUU
# TMP
# TMP
# TMP
# TMP
# TMP

# %%
tmp= response.json()['response']['body']['items']['item']
tmp_list = []
for i in range(len(tmp)):
    if(('20220811'  in tmp[i].values()) & ('0100' in tmp[i].values())):
        tmp_list.append(list(tmp[i].values()))

# %% [markdown]
# TMP 1시간기온
# PCP 1시간 강수량
# WSD 풍속
# VEC 풍향
# REH 습도

# %%
temp = []
pcp = []
wsd = []
vec = []
reh = []

for i in range(len(tmp_list)):
    if ('TMP' in tmp_list[i]):
        temp.append(tmp_list[i][5])

# %%
int('02')
# Out:
# 2

# %%
tmp_list
# Out:
# [['20220809', '2300', 'TMP', '20220811', '0100', '23', 55, 127],
#  ['20220809', '2300', 'UUU', '20220811', '0100', '0.5', 55, 127],
#  ['20220809', '2300', 'VVV', '20220811', '0100', '0.7', 55, 127],
#  ['20220809', '2300', 'VEC', '20220811', '0100', '216', 55, 127],
#  ['20220809', '2300', 'WSD', '20220811', '0100', '0.9', 55, 127],
#  ['20220809', '2300', 'SKY', '20220811', '0100', '3', 55, 127],
#  ['20220809', '2300', 'PTY', '20220811', '0100', '0', 55, 127],
#  ['20220809', '2300', 'POP', '20220811', '0100', '20', 55, 127],
#  ['20220809', '2300', 'WAV', '20220811', '0100', '0', 55, 127],
#  ['20220809', '2300', 'PCP', '20220811', '0100', '강수없음', 55, 127],
#  ['20220809', '2300', 'REH', '20220811', '0100', '90', 55, 127],
#  ['20220809', '2300', 'SNO', '20220811', '0100', '적설없음', 55, 127]]

# %%
temp
# Out:
# ['22']
